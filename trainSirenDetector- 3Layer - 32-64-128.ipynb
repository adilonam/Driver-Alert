# %%
# Last updated: GHS
# email: gabrielsarch@gmail.com
#
# Last edited: 4/25/2020

# %%
# This file trains the Convolutional Neural Network
## Uses siren, car, and background noises (split into 3-second chunks)

# *******3-Layer architecture**********

# %%
import math

RATE = 22050 #Hz - sample rate of training files

# paths to numpy array files
# These files contain numpy arrays in format (nSoundBytes x nSamples) 
# nSamples is usually = RATE*seconds
# see generateTrainingData
sirenFile = r'C:\Users\Gabe\Documents\SeniorDesign\Data\Senior Design data training\sirenNoise.npy'
backFile = r'C:\Users\Gabe\Documents\SeniorDesign\Data\Senior Design data training\backNoise.npy'
carFile = r'C:\Users\Gabe\Documents\SeniorDesign\Data\Senior Design data training\carNoise.npy'

# Where to save CNN Model WEIGHTS (not full architecture)
saveModel = 'C:/Users/Gabe/Documents/SeniorDesign/CNNModels/weights.best.basic_cnn.hdf5'

# Where to save model architecture + weights
modelSave = 'C:/Users/Gabe/Documents/Driver-Alert/Models/siren_detector_V2_3Layer.h5'

# Parameters for generateData
num_samples = 999 # number of samples used for training from each array
num_samp_noise = math.floor(num_samples/3)*4 # need more noise samples than siren samples

# %%
# Load in numpy arrays containing data & splits data up into training and validation sets (use validation for ROC curves)

import numpy as np

sirenNoise = np.load(sirenFile)
backNoise = np.load(backFile)
carNoise = np.load(carFile)

print('Array shapes before:')
print(sirenNoise.shape)
print(backNoise.shape)
print(carNoise.shape)
print(' ')

percentHeldOut = 0.1

perm = np.random.permutation(len(sirenNoise))[0:round(percentHeldOut*sirenNoise.shape[0])]
sirenNoiseVal = sirenNoise[perm]
sirenNoise = np.delete(sirenNoise, perm, axis=0)

perm = np.random.permutation(len(backNoise))[0:round(percentHeldOut*backNoise.shape[0])]
backNoiseVal = backNoise[perm]
backNoise = np.delete(backNoise, perm, axis=0)

perm = np.random.permutation(len(carNoise))[0:round(percentHeldOut*carNoise.shape[0])]
carNoiseVal = carNoise[perm]
carNoise = np.delete(carNoise, perm, axis=0)

print('Array shape after (valid, train):')
print(sirenNoiseVal.shape)
print(sirenNoise.shape)
print(backNoiseVal.shape)
print(backNoise.shape)
print(carNoiseVal.shape)
print(carNoise.shape)
# Out:
# Array shapes before:
# (1839, 66150)
# (6566, 66150)
# (613, 66150)
#
# Array shape after (valid, train):
# (184, 66150)
# (1655, 66150)
# (657, 66150)
# (5909, 66150)
# (61, 66150)
# (552, 66150)

# %%
x = True
isinstance(x,int) #or x==False
if not isinstance(x, bool):
    print('Hello')
type(x)
#raise TypeError('HI')
# Out:
# bool

# %%
from scipy import signal
import pandas as pd
import os
import librosa

sos = signal.butter(5, [50, 5000], 'bandpass', fs=RATE, output='sos')

def get_mfccs(audio):
   
    try:
        audio = 2*((audio-min(audio))/(max(audio)-min(audio)))-1

        #Filter
        audio = signal.sosfilt(sos, audio)
        
        mfccs = librosa.feature.mfcc(y=audio, sr=RATE, n_mfcc=40)

    except Exception as e:
            print("Error encountered for a file")
            return None

    return mfccs

# %%
## Fit #1

from keras.callbacks import ModelCheckpoint 
from datetime import datetime 
import random
from sklearn.model_selection import train_test_split 



def generateData(carNoise, backNoise, sirenNoise, uniformSNR=False):
# This function 
# 1) combines siren and noise data to create 2 groups: siren present group, siren not present group
# siren group: siren + car, siren + environment, siren + car + environmental (4 signal to noise ratios for each group)
# no siren group: car, environment, car + environmental 
# Then
# 2) Normalizes the audio and extracts

# Inputs:
# 1-3) car noises, background noises, siren noises (np array, nSoundBytes x nSamples)
# 4) uniformSNR - if input = false (default) training data will consist of multiple SNRs (-5, 0, 5, 10 dB SNR)
#               - if input = True will deafult to SNR of 0 dB
#               - if input = Db (integer) will do SNR of that dB
    Db5gain = 1.778279 # gain for 5dB increase

    if isinstance(uniformSNR,int):
       # if uniformSNR==True:
        #    uniformSNR = 0.0001 # Set SNR to 0 if True
        if not isinstance(uniformSNR, bool):
            if uniformSNR > 0:
                DbMult = uniformSNR/5 # Excludes if uniformSNR = False
            elif uniformSNR < 0:
                DbMult = 1/(-uniformSNR/5)
                Db5gain = 1/Db5gain
            else:
                raise TypeError('Wrong uniformSNR input')
    else:
        raise TypeError('Wrong uniformSNR input')

    start = datetime.now()

    # get desired number of samples from each array
    if len(carNoise) < num_samp_noise:
        extra = num_samp_noise - len(carNoise)
        perm = np.random.permutation(len(carNoise))
        carX = np.concatenate((carNoise[perm], carNoise[perm[0:extra]]))
        if len(carX) < num_samp_noise:
            extra = num_samp_noise - len(carX)
            perm = np.random.permutation(len(carX))
            carX = np.concatenate((carX[perm], carX[perm[0:extra]]))
    else:
        perm = np.random.permutation(len(carNoise))[0:num_samp_noise]
        carX = carNoise[perm]

    if len(backNoise) < num_samp_noise:
        extra = num_samp_noise - len(backNoise)
        perm = np.random.permutation(len(backNoise))
        envX = np.concatenate((backNoise[perm], backNoise[perm[0:extra]]))
    else:
        perm = np.random.permutation(len(backNoise))[0:num_samp_noise]
        envX = backNoise[perm]

    if len(sirenNoise) < num_samples:
        extra = num_samples - len(sirenNoise)
        perm = np.random.permutation(len(sirenNoise))
        sirenX = np.concatenate((sirenNoise[perm], sirenNoise[perm[0:extra]]))
    else:
        perm = np.random.permutation(len(sirenNoise))[0:num_samples]
        sirenX = sirenNoise[perm]


    # Add gain to background noise
    splitback1 = math.floor(num_samples/3)
    
    if uniformSNR == False:
        
        print("Mixing various SNRs")

        carX[0:splitback1] = carX[0:splitback1]*(1/(2*Db5gain))
        carX[splitback1:splitback1*2] = carX[splitback1:splitback1*2]*(1/Db5gain)
        carX[splitback1*2:splitback1*3] = carX[splitback1*2:splitback1*3]
        carX[splitback1*3:] = carX[splitback1*3:]*Db5gain

        envX[0:splitback1] = envX[0:splitback1]*(1/(2*Db5gain))
        envX[splitback1:splitback1*2] = envX[splitback1:splitback1*2]*(1/Db5gain)
        envX[splitback1*2:splitback1*3] = envX[splitback1*2:splitback1*3]
        envX[splitback1*3:] = envX[splitback1*3:]*Db5gain

        #sirenX[0:splitback1] = sirenX[0:splitback1]
        #sirenX[splitback1:splitback1*2] = envX[splitback1:splitback1*2]*Db5gain
        #sirenX[splitback1*2:splitback1*3] = envX[splitback1*2:splitback1*3]*Db5gain*2
        #sirenX[splitback1*3:] = sirenX[splitback1*3:]*Db5gain*3
        
    elif uniformSNR == True: # SNR of 0 dB
        print("SNR of 0 dB")
        sirenX = sirenX*1
    
    else:    
        print("Uniform SNR with SNR = ", uniformSNR)
        sirenX = sirenX*Db5gain*DbMult

    sirencar = sirenX[0:splitback1]+carX[0:splitback1]
    sirenenv = sirenX[splitback1:splitback1*2]+envX[0:splitback1]
    sirencarenv = sirenX[splitback1*2:splitback1*3]+carX[splitback1:splitback1*2]*0.5+envX[splitback1:splitback1*2]*0.5

    sirenSet = np.concatenate((sirencar, sirenenv, sirencarenv))
    noiseSet = np.concatenate((carX[splitback1*2:splitback1*3], envX[splitback1*2:splitback1*3], carX[splitback1*3:splitback1*4]+envX[splitback1*3:splitback1*4]))            

    print('Finished scrambling data set')
    print('Extracting MFCCs...')

    mfccSiren = []
    for i in range(0,len(sirenSet)):
        cur_audio = sirenSet[i]
        #cur_audio = 2*((cur_audio-min(cur_audio))/(max(cur_audio)-min(cur_audio)))-1
        mfcc = get_mfccs(cur_audio)
        mfccSiren.append(mfcc)
        sirenSet[i] = cur_audio

    mfccNoise = []
    for i in range(0,len(noiseSet)):
        cur_audio = noiseSet[i]
        #cur_audio = 2*((cur_audio-min(cur_audio))/(max(cur_audio)-min(cur_audio)))-1
        mfcc = get_mfccs(cur_audio)
        mfccNoise.append(mfcc)
        noiseSet[i] = cur_audio
    
    # Create labels for the data
    sirenLabels = ['siren']*len(mfccSiren) 
    noiseLabels = ['noise']*len(mfccNoise)

    # Comibine MFCCs and labels 
    featureSiren = list(zip(mfccSiren, sirenLabels))
    featureNoise = list(zip(mfccNoise, noiseLabels))
    features = featureSiren + featureNoise
    random.shuffle(features)
    
    # Convert to Panda dataframe
    featuresdf = pd.DataFrame(features, columns=['feature','class_label'])

    from sklearn.preprocessing import LabelEncoder
    from keras.utils import to_categorical

    # Convert features and corresponding classification labels into numpy arrays
    X = np.array(featuresdf.feature.tolist())
    y = np.array(featuresdf.class_label.tolist())

    # Encode the classification labels
    le = LabelEncoder()
    yy = to_categorical(le.fit_transform(y)) 

    duration = datetime.now() - start
    print("Generating training and test data took: ", duration)
    
    return X, yy
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
# Create model architecture

# Format of input data
num_rows = 40
num_columns = 130 #x_train.shape[2]
num_channels = 1

# generate data for initial model evaluation
X, yy = generateData(carNoise, backNoise, sirenNoise) 

# split the dataset 
x_train, x_test, y_train, y_test = train_test_split(X, yy, test_size=0.2)#, random_state = 42)
x_train = x_train.reshape(x_train.shape[0], num_rows, num_columns, num_channels)
x_test = x_test.reshape(x_test.shape[0], num_rows, num_columns, num_channels)

from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.layers import Convolution2D, Conv2D, MaxPooling2D, GlobalAveragePooling2D
from keras.optimizers import Adam
from keras.utils import np_utils
from sklearn import metrics 

num_labels = 2 #yy.shape[1]
filter_size = 2

# Construct model 
model = Sequential()
model.add(Conv2D(filters=32, kernel_size=filter_size, input_shape=(num_rows, num_columns, num_channels), activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.2))

model.add(Conv2D(filters=64, kernel_size=filter_size, activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.2))

model.add(Conv2D(filters=128, kernel_size=filter_size, activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.2))
model.add(GlobalAveragePooling2D())

model.add(Dense(num_labels, activation='softmax')) 

# Compile the model
model.compile(loss='binary_crossentropy', metrics=['accuracy'], optimizer='adam') 


# Summary of model

# Display model architecture summary 
model.summary()

# Calculate pre-training accuracy 
score = model.evaluate(x_test, y_test, verbose=1)
accuracy = 100*score[1]

print("Pre-training accuracy: %.4f%%" % accuracy)
# Out:
# Mixing various SNRs
# Finished scrambling data set
# Extracting MFCCs...
# Generating training and test data took:  0:02:12.825465
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_17 (Conv2D)           (None, 39, 129, 32)       160
# _________________________________________________________________
# max_pooling2d_13 (MaxPooling (None, 19, 64, 32)        0
# _________________________________________________________________
# dropout_13 (Dropout)         (None, 19, 64, 32)        0
# _________________________________________________________________
# conv2d_18 (Conv2D)           (None, 18, 63, 64)        8256
# _________________________________________________________________
# max_pooling2d_14 (MaxPooling (None, 9, 31, 64)         0
# _________________________________________________________________
# dropout_14 (Dropout)         (None, 9, 31, 64)         0
# _________________________________________________________________
# conv2d_19 (Conv2D)           (None, 8, 30, 128)        32896
# _________________________________________________________________
# max_pooling2d_15 (MaxPooling (None, 4, 15, 128)        0
# _________________________________________________________________
# dropout_15 (Dropout)         (None, 4, 15, 128)        0
# _________________________________________________________________
# global_average_pooling2d_2 ( (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 258
# =================================================================
# Total params: 41,570
# Trainable params: 41,570
# Non-trainable params: 0
# _________________________________________________________________
# 400/400 [==============================] - 1s 2ms/step
# Pre-training accuracy: 50.0000%

# %%
# Fit model by regenerating training data based on num_fits
# Each iteration of num_fits, a new combination of siren and noise is generated from the array
# adn the model weights are fit with epochs = num_epochs and batch size = num_batch_size

from keras.callbacks import ModelCheckpoint 
from datetime import datetime 

#num_epochs = 12
#num_batch_size = 128

num_fits = 4 # number of times new training data is generated and model trained

# For each fit (i.e. for iterations = num_fits):
num_epochs = 25
num_batch_size = 32

checkpointer = ModelCheckpoint(filepath=saveModel, monitor='val_loss', verbose=1, save_best_only=True, save_weights_only=False, mode='auto', period=1)

for i in range(0, num_fits):
    
    print('Generating data for fit #', i+1)

    X, yy = generateData(carNoise, backNoise, sirenNoise)
    
    # split the dataset 
    x_train, x_test, y_train, y_test = train_test_split(X, yy, test_size=0.2)#, random_state = 42)
    x_train = x_train.reshape(x_train.shape[0], num_rows, num_columns, num_channels)
    x_test = x_test.reshape(x_test.shape[0], num_rows, num_columns, num_channels)
    
    start = datetime.now()

    model.fit(x_train, y_train, batch_size=num_batch_size, epochs=num_epochs, validation_data=(x_test, y_test), callbacks=[checkpointer], verbose=1)

    duration = datetime.now() - start
    print("Training completed in time: ", duration)

    # Evaluating the model on the training and testing set
    
    print('Results from fit #', i+1)
    score = model.evaluate(x_train, y_train, verbose=0)
    print("Training Accuracy: ", score[1])

    score = model.evaluate(x_test, y_test, verbose=0)
    print("Testing Accuracy: ", score[1])
    
print('Finished model fitting')
# Out:
# Generating data for fit # 1
# Mixing various SNRs
# Finished scrambling data set
# Extracting MFCCs...
# Generating training and test data took:  0:02:11.007959
# Train on 1598 samples, validate on 400 samples
# Epoch 1/25
# 1598/1598 [==============================] - 13s 8ms/step - loss: 1.0317 - accuracy: 0.6940 - val_loss: 0.3005 - val_accuracy: 0.8825
#
# Epoch 00001: val_loss improved from inf to 0.30046, saving model to C:/Users/Gabe/Documents/SeniorDesign/CNNModels/weights.best.basic_cnn.hdf5
# Epoch 2/25
# 1598/1598 [==============================] - 13s 8ms/step - loss: 0.2680 - accuracy: 0.8930 - val_loss: 0.2074 - val_accuracy: 0.9275
#
# Epoch 00002: val_loss improved from 0.30046 to 0.20745, saving model to C:/Users/Gabe/Documents/SeniorDesign/CNNModels/weights.best.basic_cnn.hdf5
# Epoch 3/25
# 1598/1598 [==============================] - 12s 7ms/step - loss: 0.3128 - accuracy: 0.8811 - val_loss: 0.2083 - val_accuracy: 0.9250
#
# Epoch 00003: val_loss did not improve from 0.20745
# Epoch 4/25
# 1598/1598 [==============================] - 11s 7ms/step - loss: 0.2391 - accuracy: 0.9018 - val_loss: 0.1955 - val_accuracy: 0.9150
#
# Epoch 00004: val_loss improved from 0.20745 to 0.19549, saving model to C:/Users/Gabe/Documents/SeniorDesign/CNNModels/weights.best.basic_cnn.hdf5
# Epoch 5/25
# 1598/1598 [==============================] - 11s 7ms/step - loss: 0.2243 - accuracy: 0.9061 - val_loss: 0.2277 - val_accuracy: 0.9050
#
# Epoch 00005: val_loss did not improve from 0.19549
# Epoch 6/25
# 1598/1598 [==============================] - 10s 6ms/step - loss: 0.2372 - accuracy: 0.8986 - val_loss: 0.2682 - val_accuracy: 0.8775
#
# Epoch 00006: val_loss did not improve from 0.19549
# Epoch 7/25
# 1598/1598 [==============================] - 11s 7ms/step - loss: 0.2017 - accuracy: 0.9199 - val_loss: 0.2155 - val_accuracy: 0.9175
#
# Epoch 00007: val_loss did not improve from 0.19549
# Epoch 8/25
# 1598/1598 [==============================] - 11s 7ms/step - loss: 0.2111 - accuracy: 0.9136 - val_loss: 0.2402 - val_accuracy: 0.8975
#
# Epoch 00008: val_loss did not improve from 0.19549
# Epoch 9/25
# 1598/1598 [==============================] - 11s 7ms/step - loss: 0.2117 - accuracy: 0.9149 - val_loss: 0.1871 - val_accuracy: 0.9250
#
# Epoch 00009: val_loss improved from 0.19549 to 0.18707, saving model to C:/Users/Gabe/Documents/SeniorDesign/CNNModels/weights.best.basic_cnn.hdf5
# Epoch 10/25
# 1598/1598 [==============================] - 11s 7ms/step - loss: 0.1897 - accuracy: 0.9218 - val_loss: 0.1900 - val_accuracy: 0.9100
#
# Epoch 00010: val_loss did not improve from 0.18707
# Epoch 11/25
# 1598/1598 [==============================] - 11s 7ms/step - loss: 0.2153 - accuracy: 0.9111 - val_loss: 0.2520 - val_accuracy: 0.8975
#
# Epoch 00011: val_loss did not improve from 0.18707
# Epoch 12/25
# 1598/1598 [==============================] - 12s 8ms/step - loss: 0.2025 - accuracy: 0.9205 - val_loss: 0.2212 - val_accuracy: 0.9175
#
# Epoch 00012: val_loss did not improve from 0.18707
# Epoch 13/25
# 1598/1598 [==============================] - 11s 7ms/step - loss: 0.1896 - accuracy: 0.9230 - val_loss: 0.1940 - val_accuracy: 0.9225
#
# Epoch 00013: val_loss did not improve from 0.18707
# Epoch 14/25
# 1598/1598 [==============================] - 11s 7ms/step - loss: 0.1800 - accuracy: 0.9249 - val_loss: 0.1808 - val_accuracy: 0.9275
#
# Epoch 00014: val_loss improved from 0.18707 to 0.18082, saving model to C:/Users/Gabe/Documents/SeniorDesign/CNNModels/weights.best.basic_cnn.hdf5
# Epoch 15/25
# 1598/1598 [==============================] - 12s 7ms/step - loss: 0.1761 - accuracy: 0.9293 - val_loss: 0.1830 - val_accuracy: 0.9225
#
# Epoch 00015: val_loss did not improve from 0.18082
# Epoch 16/25
# 1598/1598 [==============================] - 13s 8ms/step - loss: 0.1962 - accuracy: 0.9186 - val_loss: 0.2107 - val_accuracy: 0.9350
#
# Epoch 00016: val_loss did not improve from 0.18082
# Epoch 17/25
# 1598/1598 [==============================] - 11s 7ms/step - loss: 0.1748 - accuracy: 0.9243 - val_loss: 0.1913 - val_accuracy: 0.9300
#
# Epoch 00017: val_loss did not improve from 0.18082
# Epoch 18/25
# 1598/1598 [==============================] - 14s 9ms/step - loss: 0.1657 - accuracy: 0.9318 - val_loss: 0.1834 - val_accuracy: 0.9300
#
# Epoch 00018: val_loss did not improve from 0.18082
# Epoch 19/25
# 1598/1598 [==============================] - 11s 7ms/step - loss: 0.1751 - accuracy: 0.9224 - val_loss: 0.1733 - val_accuracy: 0.9300
#
# Epoch 00019: val_loss improved from 0.18082 to 0.17325, saving model to C:/Users/Gabe/Documents/SeniorDesign/CNNModels/weights.best.basic_cnn.hdf5
# Epoch 20/25
# 1598/1598 [==============================] - 11s 7ms/step - loss: 0.1631 - accuracy: 0.9287 - val_loss: 0.1667 - val_accuracy: 0.9350
#
# Epoch 00020: val_loss improved from 0.17325 to 0.16672, saving model to C:/Users/Gabe/Documents/SeniorDesign/CNNModels/weights.best.basic_cnn.hdf5
# Epoch 21/25
# 1598/1598 [==============================] - 11s 7ms/step - loss: 0.1658 - accuracy: 0.9305 - val_loss: 0.1646 - val_accuracy: 0.9275
#
# Epoch 00021: val_loss improved from 0.16672 to 0.16461, saving model to C:/Users/Gabe/Documents/SeniorDesign/CNNModels/weights.best.basic_cnn.hdf5
# Epoch 22/25
# 1598/1598 [==============================] - 11s 7ms/step - loss: 0.1656 - accuracy: 0.9230 - val_loss: 0.2012 - val_accuracy: 0.9250
#
# Epoch 00022: val_loss did not improve from 0.16461
# Epoch 23/25
# 1598/1598 [==============================] - 11s 7ms/step - loss: 0.1538 - accuracy: 0.9293 - val_loss: 0.1637 - val_accuracy: 0.9450
#
# Epoch 00023: val_loss improved from 0.16461 to 0.16370, saving model to C:/Users/Gabe/Documents/SeniorDesign/CNNModels/weights.best.basic_cnn.hdf5
# Epoch 24/25
# 1598/1598 [==============================] - 10s 6ms/step - loss: 0.1455 - accuracy: 0.9374 - val_loss: 0.1579 - val_accuracy: 0.9400
#
# Epoch 00024: val_loss improved from 0.16370 to 0.15785, saving model to C:/Users/Gabe/Documents/SeniorDesign/CNNModels/weights.best.basic_cnn.hdf5
# Epoch 25/25
# 1598/1598 [==============================] - 9s 6ms/step - loss: 0.1543 - accuracy: 0.9305 - val_loss: 0.1810 - val_accuracy: 0.9250
#
# Epoch 00025: val_loss did not improve from 0.15785
# Training completed in time:  0:04:45.941841
# Results from fit # 1
# Training Accuracy:  0.9430538415908813
# Testing Accuracy:  0.925000011920929
# Generating data for fit # 2
# Mixing various SNRs
# Finished scrambling data set
# Extracting MFCCs...
# Generating training and test data took:  0:02:08.342209
# Train on 1598 samples, validate on 400 samples
# Epoch 1/25
# 1598/1598 [==============================] - 9s 6ms/step - loss: 0.1695 - accuracy: 0.9299 - val_loss: 0.1785 - val_accuracy: 0.9350
#
# Epoch 00001: val_loss did not improve from 0.15785
# Epoch 2/25
# 1598/1598 [==============================] - 9s 6ms/step - loss: 0.1834 - accuracy: 0.9287 - val_loss: 0.1761 - val_accuracy: 0.9425
#
# Epoch 00002: val_loss did not improve from 0.15785
# Epoch 3/25
# 1598/1598 [==============================] - 9s 6ms/step - loss: 0.1401 - accuracy: 0.9456 - val_loss: 0.1441 - val_accuracy: 0.9500
#
# Epoch 00003: val_loss improved from 0.15785 to 0.14408, saving model to C:/Users/Gabe/Documents/SeniorDesign/CNNModels/weights.best.basic_cnn.hdf5
# Epoch 4/25
# 1598/1598 [==============================] - 9s 5ms/step - loss: 0.1406 - accuracy: 0.9437 - val_loss: 0.1279 - val_accuracy: 0.9500
#
# Epoch 00004: val_loss improved from 0.14408 to 0.12791, saving model to C:/Users/Gabe/Documents/SeniorDesign/CNNModels/weights.best.basic_cnn.hdf5
# Epoch 5/25
# 1598/1598 [==============================] - 9s 6ms/step - loss: 0.1488 - accuracy: 0.9406 - val_loss: 0.1650 - val_accuracy: 0.9450
#
# Epoch 00005: val_loss did not improve from 0.12791
# Epoch 6/25
# 1598/1598 [==============================] - 9s 6ms/step - loss: 0.1452 - accuracy: 0.9412 - val_loss: 0.1361 - val_accuracy: 0.9525
#
# Epoch 00006: val_loss did not improve from 0.12791
# Epoch 7/25
# 1598/1598 [==============================] - 9s 6ms/step - loss: 0.1355 - accuracy: 0.9449 - val_loss: 0.1418 - val_accuracy: 0.9425
#
# Epoch 00007: val_loss did not improve from 0.12791
# Epoch 8/25
# 1598/1598 [==============================] - 9s 6ms/step - loss: 0.1375 - accuracy: 0.9493 - val_loss: 0.1504 - val_accuracy: 0.9400
#
# Epoch 00008: val_loss did not improve from 0.12791
# Epoch 9/25
# 1598/1598 [==============================] - 9s 6ms/step - loss: 0.1320 - accuracy: 0.9437 - val_loss: 0.1380 - val_accuracy: 0.9500
#
# Epoch 00009: val_loss did not improve from 0.12791
# Epoch 10/25
# 1598/1598 [==============================] - 9s 6ms/step - loss: 0.1371 - accuracy: 0.9474 - val_loss: 0.1279 - val_accuracy: 0.9475
#
# Epoch 00010: val_loss improved from 0.12791 to 0.12788, saving model to C:/Users/Gabe/Documents/SeniorDesign/CNNModels/weights.best.basic_cnn.hdf5
# Epoch 11/25
# 1598/1598 [==============================] - 9s 5ms/step - loss: 0.1349 - accuracy: 0.9468 - val_loss: 0.1220 - val_accuracy: 0.9525
#
# Epoch 00011: val_loss improved from 0.12788 to 0.12195, saving model to C:/Users/Gabe/Documents/SeniorDesign/CNNModels/weights.best.basic_cnn.hdf5
# Epoch 12/25
# 1598/1598 [==============================] - 9s 6ms/step - loss: 0.1196 - accuracy: 0.9549 - val_loss: 0.1322 - val_accuracy: 0.9525
#
# Epoch 00012: val_loss did not improve from 0.12195
# Epoch 13/25
# 1598/1598 [==============================] - 9s 5ms/step - loss: 0.1231 - accuracy: 0.9518 - val_loss: 0.1369 - val_accuracy: 0.9550
#
# Epoch 00013: val_loss did not improve from 0.12195
# Epoch 14/25
# 1598/1598 [==============================] - 9s 6ms/step - loss: 0.1206 - accuracy: 0.9531 - val_loss: 0.1279 - val_accuracy: 0.9575
#
# Epoch 00014: val_loss did not improve from 0.12195
# Epoch 15/25
# 1598/1598 [==============================] - 9s 5ms/step - loss: 0.1121 - accuracy: 0.9581 - val_loss: 0.1510 - val_accuracy: 0.9450
#
# Epoch 00015: val_loss did not improve from 0.12195
# Epoch 16/25
# 1598/1598 [==============================] - 9s 6ms/step - loss: 0.1066 - accuracy: 0.9581 - val_loss: 0.1558 - val_accuracy: 0.9350
#
# Epoch 00016: val_loss did not improve from 0.12195
# Epoch 17/25
# 1598/1598 [==============================] - 9s 5ms/step - loss: 0.1061 - accuracy: 0.9599 - val_loss: 0.1658 - val_accuracy: 0.9275
#
# Epoch 00017: val_loss did not improve from 0.12195
# Epoch 18/25
# 1598/1598 [==============================] - 9s 6ms/step - loss: 0.1037 - accuracy: 0.9606 - val_loss: 0.1255 - val_accuracy: 0.9575
#
# Epoch 00018: val_loss did not improve from 0.12195
# Epoch 19/25
# 1598/1598 [==============================] - 9s 6ms/step - loss: 0.1219 - accuracy: 0.9549 - val_loss: 0.1369 - val_accuracy: 0.9575
#
# Epoch 00019: val_loss did not improve from 0.12195
# Epoch 20/25
# 1598/1598 [==============================] - 9s 6ms/step - loss: 0.1017 - accuracy: 0.9637 - val_loss: 0.1250 - val_accuracy: 0.9625
#
# Epoch 00020: val_loss did not improve from 0.12195
# Epoch 21/25
# 1598/1598 [==============================] - 9s 5ms/step - loss: 0.1104 - accuracy: 0.9606 - val_loss: 0.1515 - val_accuracy: 0.9325
#
# Epoch 00021: val_loss did not improve from 0.12195
# Epoch 22/25
# 1598/1598 [==============================] - 9s 6ms/step - loss: 0.1020 - accuracy: 0.9618 - val_loss: 0.1391 - val_accuracy: 0.9525
#
# Epoch 00022: val_loss did not improve from 0.12195
# Epoch 23/25
# 1598/1598 [==============================] - 9s 6ms/step - loss: 0.1108 - accuracy: 0.9587 - val_loss: 0.1363 - val_accuracy: 0.9500
#
# Epoch 00023: val_loss did not improve from 0.12195
# Epoch 24/25
# 1598/1598 [==============================] - 9s 6ms/step - loss: 0.1375 - accuracy: 0.9512 - val_loss: 0.1408 - val_accuracy: 0.9500
#
# Epoch 00024: val_loss did not improve from 0.12195
# Epoch 25/25
# 1598/1598 [==============================] - 9s 6ms/step - loss: 0.0903 - accuracy: 0.9668 - val_loss: 0.1346 - val_accuracy: 0.9600
#
# Epoch 00025: val_loss did not improve from 0.12195
# Training completed in time:  0:03:44.138608
# Results from fit # 2
# Training Accuracy:  0.9730913639068604
# Testing Accuracy:  0.9599999785423279
# Generating data for fit # 3
# Mixing various SNRs
# Finished scrambling data set
# Extracting MFCCs...
# Generating training and test data took:  0:01:55.223875
# Train on 1598 samples, validate on 400 samples
# Epoch 1/25
# 1598/1598 [==============================] - 9s 5ms/step - loss: 0.1617 - accuracy: 0.9456 - val_loss: 0.1982 - val_accuracy: 0.9325
#
# Epoch 00001: val_loss did not improve from 0.12195
# Epoch 2/25
# 1598/1598 [==============================] - 9s 6ms/step - loss: 0.1359 - accuracy: 0.9481 - val_loss: 0.2268 - val_accuracy: 0.9250
#
# Epoch 00002: val_loss did not improve from 0.12195
# Epoch 3/25
# 1598/1598 [==============================] - 9s 5ms/step - loss: 0.1279 - accuracy: 0.9537 - val_loss: 0.1743 - val_accuracy: 0.9525
#
# Epoch 00003: val_loss did not improve from 0.12195
# Epoch 4/25
# 1598/1598 [==============================] - 9s 6ms/step - loss: 0.1317 - accuracy: 0.9531 - val_loss: 0.2646 - val_accuracy: 0.9075
#
# Epoch 00004: val_loss did not improve from 0.12195
# Epoch 5/25
# 1598/1598 [==============================] - 9s 5ms/step - loss: 0.1296 - accuracy: 0.9456 - val_loss: 0.2034 - val_accuracy: 0.9350
#
# Epoch 00005: val_loss did not improve from 0.12195
# Epoch 6/25
# 1598/1598 [==============================] - 9s 6ms/step - loss: 0.1100 - accuracy: 0.9549 - val_loss: 0.1784 - val_accuracy: 0.9425
#
# Epoch 00006: val_loss did not improve from 0.12195
# Epoch 7/25
# 1598/1598 [==============================] - 9s 6ms/step - loss: 0.1018 - accuracy: 0.9625 - val_loss: 0.1500 - val_accuracy: 0.9550
#
# Epoch 00007: val_loss did not improve from 0.12195
# Epoch 8/25
# 1598/1598 [==============================] - 9s 6ms/step - loss: 0.1181 - accuracy: 0.9543 - val_loss: 0.1554 - val_accuracy: 0.9600
#
# Epoch 00008: val_loss did not improve from 0.12195
# Epoch 9/25
# 1598/1598 [==============================] - 9s 5ms/step - loss: 0.1002 - accuracy: 0.9606 - val_loss: 0.1432 - val_accuracy: 0.9600
#
# Epoch 00009: val_loss did not improve from 0.12195
# Epoch 10/25
# 1598/1598 [==============================] - 9s 6ms/step - loss: 0.0901 - accuracy: 0.9637 - val_loss: 0.1291 - val_accuracy: 0.9675
#
# Epoch 00010: val_loss did not improve from 0.12195
# Epoch 11/25
# 1598/1598 [==============================] - 9s 6ms/step - loss: 0.0854 - accuracy: 0.9681 - val_loss: 0.1715 - val_accuracy: 0.9400
#
# Epoch 00011: val_loss did not improve from 0.12195
# Epoch 12/25
# 1598/1598 [==============================] - 9s 6ms/step - loss: 0.0876 - accuracy: 0.9631 - val_loss: 0.1627 - val_accuracy: 0.9475
#
# Epoch 00012: val_loss did not improve from 0.12195
# Epoch 13/25
# 1598/1598 [==============================] - 9s 6ms/step - loss: 0.0869 - accuracy: 0.9643 - val_loss: 0.2150 - val_accuracy: 0.9375
#
# Epoch 00013: val_loss did not improve from 0.12195
# Epoch 14/25
# 1598/1598 [==============================] - 9s 5ms/step - loss: 0.0983 - accuracy: 0.9662 - val_loss: 0.1790 - val_accuracy: 0.9375
#
# Epoch 00014: val_loss did not improve from 0.12195
# Epoch 15/25
# 1598/1598 [==============================] - 9s 6ms/step - loss: 0.0960 - accuracy: 0.9556 - val_loss: 0.1555 - val_accuracy: 0.9550
#
# Epoch 00015: val_loss did not improve from 0.12195
# Epoch 16/25
# 1598/1598 [==============================] - 9s 5ms/step - loss: 0.0803 - accuracy: 0.9662 - val_loss: 0.1841 - val_accuracy: 0.9525
#
# Epoch 00016: val_loss did not improve from 0.12195
# Epoch 17/25
# 1598/1598 [==============================] - 9s 6ms/step - loss: 0.0832 - accuracy: 0.9681 - val_loss: 0.1813 - val_accuracy: 0.9550
#
# Epoch 00017: val_loss did not improve from 0.12195
# Epoch 18/25
# 1598/1598 [==============================] - 9s 5ms/step - loss: 0.0784 - accuracy: 0.9681 - val_loss: 0.1974 - val_accuracy: 0.9500
#
# Epoch 00018: val_loss did not improve from 0.12195
# Epoch 19/25
# 1598/1598 [==============================] - 9s 6ms/step - loss: 0.0870 - accuracy: 0.9712 - val_loss: 0.1590 - val_accuracy: 0.9475
#
# Epoch 00019: val_loss did not improve from 0.12195
# Epoch 20/25
# 1598/1598 [==============================] - 9s 5ms/step - loss: 0.0680 - accuracy: 0.9712 - val_loss: 0.1738 - val_accuracy: 0.9475
#
# Epoch 00020: val_loss did not improve from 0.12195
# Epoch 21/25
# 1598/1598 [==============================] - 9s 6ms/step - loss: 0.0684 - accuracy: 0.9762 - val_loss: 0.1788 - val_accuracy: 0.9500
#
# Epoch 00021: val_loss did not improve from 0.12195
# Epoch 22/25
# 1598/1598 [==============================] - 9s 6ms/step - loss: 0.0653 - accuracy: 0.9737 - val_loss: 0.1576 - val_accuracy: 0.9550
#
# Epoch 00022: val_loss did not improve from 0.12195
# Epoch 23/25
# 1598/1598 [==============================] - 9s 6ms/step - loss: 0.0689 - accuracy: 0.9718 - val_loss: 0.1743 - val_accuracy: 0.9500
#
# Epoch 00023: val_loss did not improve from 0.12195
# Epoch 24/25
# 1598/1598 [==============================] - 9s 6ms/step - loss: 0.0516 - accuracy: 0.9800 - val_loss: 0.1554 - val_accuracy: 0.9575
#
# Epoch 00024: val_loss did not improve from 0.12195
# Epoch 25/25
# 1598/1598 [==============================] - 9s 6ms/step - loss: 0.0658 - accuracy: 0.9725 - val_loss: 0.1615 - val_accuracy: 0.9575
#
# Epoch 00025: val_loss did not improve from 0.12195
# Training completed in time:  0:03:43.013615
# Results from fit # 3
# Training Accuracy:  0.9893617033958435
# Testing Accuracy:  0.9574999809265137
# Generating data for fit # 4
# Mixing various SNRs
# Finished scrambling data set
# Extracting MFCCs...
# Generating training and test data took:  0:01:50.379629
# Train on 1598 samples, validate on 400 samples
# Epoch 1/25
# 1598/1598 [==============================] - 9s 5ms/step - loss: 0.1576 - accuracy: 0.9449 - val_loss: 0.1143 - val_accuracy: 0.9525
#
# Epoch 00001: val_loss improved from 0.12195 to 0.11425, saving model to C:/Users/Gabe/Documents/SeniorDesign/CNNModels/weights.best.basic_cnn.hdf5
# Epoch 2/25
# 1598/1598 [==============================] - 9s 6ms/step - loss: 0.1455 - accuracy: 0.9493 - val_loss: 0.1545 - val_accuracy: 0.9375
#
# Epoch 00002: val_loss did not improve from 0.11425
# Epoch 3/25
# 1598/1598 [==============================] - 9s 5ms/step - loss: 0.1204 - accuracy: 0.9524 - val_loss: 0.1065 - val_accuracy: 0.9525
#
# Epoch 00003: val_loss improved from 0.11425 to 0.10648, saving model to C:/Users/Gabe/Documents/SeniorDesign/CNNModels/weights.best.basic_cnn.hdf5
# Epoch 4/25
# 1598/1598 [==============================] - 9s 6ms/step - loss: 0.1197 - accuracy: 0.9543 - val_loss: 0.1319 - val_accuracy: 0.9300
#
# Epoch 00004: val_loss did not improve from 0.10648
# Epoch 5/25
# 1598/1598 [==============================] - 9s 6ms/step - loss: 0.1051 - accuracy: 0.9625 - val_loss: 0.1293 - val_accuracy: 0.9425
#
# Epoch 00005: val_loss did not improve from 0.10648
# Epoch 6/25
# 1598/1598 [==============================] - 9s 6ms/step - loss: 0.1000 - accuracy: 0.9618 - val_loss: 0.1223 - val_accuracy: 0.9425
#
# Epoch 00006: val_loss did not improve from 0.10648
# Epoch 7/25
# 1598/1598 [==============================] - 9s 6ms/step - loss: 0.1119 - accuracy: 0.9518 - val_loss: 0.1107 - val_accuracy: 0.9450
#
# Epoch 00007: val_loss did not improve from 0.10648
# Epoch 8/25
# 1598/1598 [==============================] - 9s 5ms/step - loss: 0.1008 - accuracy: 0.9650 - val_loss: 0.1194 - val_accuracy: 0.9500
#
# Epoch 00008: val_loss did not improve from 0.10648
# Epoch 9/25
# 1598/1598 [==============================] - 9s 6ms/step - loss: 0.0854 - accuracy: 0.9681 - val_loss: 0.1218 - val_accuracy: 0.9500
#
# Epoch 00009: val_loss did not improve from 0.10648
# Epoch 10/25
# 1598/1598 [==============================] - 9s 5ms/step - loss: 0.0791 - accuracy: 0.9700 - val_loss: 0.1001 - val_accuracy: 0.9525
#
# Epoch 00010: val_loss improved from 0.10648 to 0.10008, saving model to C:/Users/Gabe/Documents/SeniorDesign/CNNModels/weights.best.basic_cnn.hdf5
# Epoch 11/25
# 1598/1598 [==============================] - 9s 6ms/step - loss: 0.0861 - accuracy: 0.9693 - val_loss: 0.1507 - val_accuracy: 0.9425
#
# Epoch 00011: val_loss did not improve from 0.10008
# Epoch 12/25
# 1598/1598 [==============================] - 9s 5ms/step - loss: 0.0936 - accuracy: 0.9618 - val_loss: 0.1222 - val_accuracy: 0.9525
#
# Epoch 00012: val_loss did not improve from 0.10008
# Epoch 13/25
# 1598/1598 [==============================] - 9s 6ms/step - loss: 0.0746 - accuracy: 0.9718 - val_loss: 0.1120 - val_accuracy: 0.9525
#
# Epoch 00013: val_loss did not improve from 0.10008
# Epoch 14/25
# 1598/1598 [==============================] - 9s 5ms/step - loss: 0.0818 - accuracy: 0.9668 - val_loss: 0.1040 - val_accuracy: 0.9450
#
# Epoch 00014: val_loss did not improve from 0.10008
# Epoch 15/25
# 1598/1598 [==============================] - 9s 6ms/step - loss: 0.0787 - accuracy: 0.9725 - val_loss: 0.1204 - val_accuracy: 0.9550
#
# Epoch 00015: val_loss did not improve from 0.10008
# Epoch 16/25
# 1598/1598 [==============================] - 9s 5ms/step - loss: 0.0820 - accuracy: 0.9675 - val_loss: 0.1414 - val_accuracy: 0.9525
#
# Epoch 00016: val_loss did not improve from 0.10008
# Epoch 17/25
# 1598/1598 [==============================] - 9s 6ms/step - loss: 0.0787 - accuracy: 0.9725 - val_loss: 0.1447 - val_accuracy: 0.9475
#
# Epoch 00017: val_loss did not improve from 0.10008
# Epoch 18/25
# 1598/1598 [==============================] - 9s 6ms/step - loss: 0.0868 - accuracy: 0.9625 - val_loss: 0.1714 - val_accuracy: 0.9425
#
# Epoch 00018: val_loss did not improve from 0.10008
# Epoch 19/25
# 1598/1598 [==============================] - 9s 6ms/step - loss: 0.0671 - accuracy: 0.9743 - val_loss: 0.1457 - val_accuracy: 0.9500
#
# Epoch 00019: val_loss did not improve from 0.10008
# Epoch 20/25
# 1598/1598 [==============================] - 9s 6ms/step - loss: 0.0610 - accuracy: 0.9793 - val_loss: 0.1539 - val_accuracy: 0.9500
#
# Epoch 00020: val_loss did not improve from 0.10008
# Epoch 21/25
# 1598/1598 [==============================] - 9s 5ms/step - loss: 0.0591 - accuracy: 0.9737 - val_loss: 0.1517 - val_accuracy: 0.9425
#
# Epoch 00021: val_loss did not improve from 0.10008
# Epoch 22/25
# 1598/1598 [==============================] - 9s 6ms/step - loss: 0.0629 - accuracy: 0.9775 - val_loss: 0.1388 - val_accuracy: 0.9400
#
# Epoch 00022: val_loss did not improve from 0.10008
# Epoch 23/25
# 1598/1598 [==============================] - 9s 5ms/step - loss: 0.0587 - accuracy: 0.9812 - val_loss: 0.1293 - val_accuracy: 0.9500
#
# Epoch 00023: val_loss did not improve from 0.10008
# Epoch 24/25
# 1598/1598 [==============================] - 9s 6ms/step - loss: 0.0592 - accuracy: 0.9737 - val_loss: 0.1965 - val_accuracy: 0.9425
#
# Epoch 00024: val_loss did not improve from 0.10008
# Epoch 25/25
# 1598/1598 [==============================] - 9s 5ms/step - loss: 0.0535 - accuracy: 0.9819 - val_loss: 0.1371 - val_accuracy: 0.9375
#
# Epoch 00025: val_loss did not improve from 0.10008
# Training completed in time:  0:03:43.362650
# Results from fit # 4
# Training Accuracy:  0.9893617033958435
# Testing Accuracy:  0.9375
# Finished model fitting

# %%
# Save model

model.save(modelSave)

# %%
#Loads model
# Do not have to run if already trained
from keras.models import load_model

modelSave = 'C:/Users/Gabe/Documents/Driver-Alert/Models/siren_detector_V2_3Layer.h5' # location of the trained model
model = load_model(modelSave)

# %%
# Compute ROC curve for validation data

num_samples = sirenNoiseVal.shape[0]

# %%
# Compute ROC for various SNRs

num_samples = sirenNoiseVal.shape[0]

from sklearn.metrics import roc_curve
from numpy import ravel
from sklearn.metrics import auc
import matplotlib.pyplot as plt

num_rows = 40
num_columns = 130 #x_train.shape[2]
num_channels = 1

def plotROC(sirenSNR, Title):

    num_samples = sirenNoiseVal.shape[0]
    X, yy = generateData(carNoiseVal, backNoiseVal, sirenNoiseVal, sirenSNR)

    X = X.reshape(X.shape[0], num_rows, num_columns, num_channels)

    y_pred_keras = model.predict_proba(X)
    predicted_proba = y_pred_keras[:,1]
    desc_score_indices = np.argsort(predicted_proba, kind="mergesort")[::-1]
    y_pred = predicted_proba

    y_test2 = yy[:,1]

    y_pred_keras = model.predict_proba(X)

    fpr_keras, tpr_keras, thresholds_keras = roc_curve(y_test2, y_pred)

    auc_keras = auc(fpr_keras, tpr_keras)

    # plot
    plt.figure(1)
    plt.plot([0, 1], [0, 1], 'k--')
    plt.plot(fpr_keras, tpr_keras, label='ROC (area = {:.3f})'.format(auc_keras))
    plt.xlabel('False positive rate')
    plt.ylabel('True positive rate')
    plt.title(Title)
    plt.legend(loc='best')
    plt.show()

# %%
# Mixed SNRs: (-5, 0, 5, 10 dB SNR)

plotROC(False, 'ROC curve: Mixed SNR')
# Out:
# Mixing various SNRs
# Finished scrambling data set
# Extracting MFCCs...
# Generating training and test data took:  0:00:24.459748

# %%
# SNR of -10 dB

plotROC(-10, 'ROC curve: -10 dB SNR')
# Out:
# Uniform SNR with SNR =  -10
# Finished scrambling data set
# Extracting MFCCs...
# Generating training and test data took:  0:00:21.629604

# %%
# SNR of -5 dB

plotROC(-5, 'ROC curve: -5 dB SNR')
# Out:
# Uniform SNR with SNR =  -5
# Finished scrambling data set
# Extracting MFCCs...
# Generating training and test data took:  0:00:19.886817

# %%
# SNR of 0 dB

plotROC(True, 'ROC curve: 0 dB SNR')
# Out:
# SNR of 0 dB
# Finished scrambling data set
# Extracting MFCCs...
# Generating training and test data took:  0:00:22.216620

# %%
# SNR of 5 dB

plotROC(5, 'ROC curve: 5 dB SNR')
# Out:
# Uniform SNR with SNR =  5
# Finished scrambling data set
# Extracting MFCCs...
# Generating training and test data took:  0:00:20.735734

# %%
# SNR of 10 dB

plotROC(10, 'ROC curve: 10 dB SNR')
# Out:
# Uniform SNR with SNR =  10
# Finished scrambling data set
# Extracting MFCCs...
# Generating training and test data took:  0:00:20.991411

# %%
# SNR of 15 dB

plotROC(15, 'ROC curve: 15 dB SNR')
# Out:
# Uniform SNR with SNR =  15
# Finished scrambling data set
# Extracting MFCCs...
# Generating training and test data took:  0:00:21.127090

# %%
# SNR of 20 dB

plotROC(20)
# Out:
# Uniform SNR with SNR =  20
# Finished scrambling data set
# Extracting MFCCs...
# Generating training and test data took:  0:00:22.773780

# %%
plotROC(0.5)

# %%
plt.figure(1)
plt.plot([0, 1], [0, 1], 'k--')
plt.plot(fpr_keras, tpr_keras, label='ROC (area = {:.3f})'.format(auc_keras))
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.title('ROC curve')
plt.legend(loc='best')
plt.show()

# %%
# Test various sounds

import sounddevice as sd
import time
startPlay = 0 # Where to start index
amountPlay = 5 # seconds
for i in list(range(startPlay, amountPlay+startPlay)):
    sd.play(sirenSet[i,:], RATE)
    time.sleep(3)
